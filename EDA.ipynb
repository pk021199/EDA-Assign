# %% [markdown]
# 1. Read the Bike Details dataset into a Pandas DataFrame and display its
# first 10 rows.
#  - [link text](file:///C:/Users/Yaman/Downloads/Bike_Details_First10.pdf)

# %% [markdown]
# 2. Check for missing values in all columns and describe your approach for
# handling them.
# - Here’s what I found about missing values in the Bike Details dataset:
#   * name: 0 missing
#   * selling_price: 0 missing
#   * year: 0 missing
#   * seller_type: 0 missing
#   * owner: 0 missing
#   * km_driven: 0 missing
#   * ex_showroom_price: 435 missing values
#
#   **Approach for Handling Missing Values:**
#   1. Identify Importance of the Column
#      * The missing values are only in ex_showroom_price.
#      * This column represents the original showroom price, which can be useful for comparing depreciation against selling_price.
#   2. Possible Strategies
#      * If analysis needs all data: Drop rows with missing ex_showroom_price (reduces dataset size).
#      * If preserving all rows is important: Impute missing values. Options:
#        * Mean/Median Imputation: Replace with the median price grouped by name (bike model).
#        * Model-based Imputation: Predict showroom price using regression, considering year, selling_price, and km_driven.
#        * Leave as Missing (NaN): If the column isn’t central to the analysis.
#   3. Recommended Choice
#      * Since showroom price usually depends on the bike model (name) and year, I’d suggest filling missing values with the median showroom price of the same bike model and year.
#      * If that’s not available, fallback to the overall median.

# %% [markdown]
# 3. Plot the distribution of selling prices using a histogram and describe the
# overall trend.
#  - ![image.png](data:image/png;base64,...)
#
#      **Observations:**
#      * The distribution is right-skewed:
#        Most bikes have lower selling prices, while a few high-priced bikes stretch the distribution to the right.
#      * A large concentration is seen in the ₹20,000 – ₹100,000 range, suggesting that most bikes in the dataset are budget to mid-range.
#      * Very few bikes have prices above ₹200,000, indicating they are premium or luxury models (like Royal Enfield or superbikes).

# %% [markdown]
# 4. Create a bar plot to visualize the average selling price for each seller_type
# and write one observation.
#  - ![image.png](data:image/png;base64,...)
#
#      **Observation:**
#      * Individual sellers have a higher average selling price (~₹59,712) compared to dealers (~₹46,667).
#      * This suggests that bikes sold by dealers are generally priced lower, possibly because they deal in older, more affordable stock, while individuals may sell relatively newer or better-maintained bikes at higher prices.

# %% [markdown]
# 5. Compute the average km_driven for each ownership type (1st owner,
# 2nd owner, etc.), and present the result as a bar plot.
#  - ![image.png](data:image/png;base64,...)
#
#      **Results:**
#      * 1st owner bikes: ~32,817 km on average
#      * 2nd owner bikes: ~39,289 km on average
#      * 3rd owner bikes: ~33,292 km on average
#      * 4th owner bikes: ~311,500 km on average (⚠️ extremely high, likely an outlier or data entry error)
#
#      **Observation:**
#
#      As expected, 2nd and 3rd owner bikes generally have more kilometers driven compared to 1st owner bikes. However, the 4th owner category shows an unusually high average, which suggests either incorrect entries or exceptional cases.

# %% [markdown]
# 6. Use the IQR method to detect and remove outliers from the km_driven
# column. Show before-and-after summary statistics.
#  -  Before Removing Outliers
#      * Count: 1061
#      * Mean: 34,360 km
#      * Std Dev: 51,623 km
#      * Min: 350 km
#      * Max: 880,000 km
#
#      After Removing Outliers
#      * Count: 1022
#      * Mean: 28,203 km
#      * Std Dev: 19,552 km
#      * Min: 350 km
#      * Max: 86,000 km
#
#      **Observation:**
#      * Outliers (e.g., 311,500 km and 880,000 km) were removed.
#      * The maximum realistic mileage is now 86,000 km, which makes sense for used bikes.
#      * The average mileage dropped from 34,360 km → 28,203 km, reflecting a more realistic usage pattern.

# %% [markdown]
# 7. Create a scatter plot of year vs. selling_price to explore the
# relationship between a bike's age and its price.
# - ![image.png](data:image/png;base64,...)
#
#      **Observations:**
#      * Newer bikes (recent years) generally have higher selling prices.
#      * Older bikes (earlier years) show lower prices, though there are a few exceptions (premium bikes like Royal Enfield may retain higher resale value).
#      * The relationship is not perfectly linear—while age affects price, other factors (brand, model, condition) also play a role.

# %% [markdown]
# 8.  Convert the seller_type column into numeric format using one-hot
# encoding. Display the first 5 rows of the resulting DataFrame.
# - [link text](file:///C:/Users/Yaman/Downloads/Bike_Details_Encoded_First5.pdf)

# %% [markdown]
# 9. Generate a heatmap of the correlation matrix for all numeric columns.
# What correlations stand out the most?
# - ![image.png](data:image/png;base64,...)
#
# **Key Correlations:**
# 1. Strong Positive Correlation
#      * selling_price ↔ ex_showroom_price (0.92)
#      → Expected, since the showroom price strongly influences resale value.
#
# 2. Negative Correlation
#      * selling_price ↔ km_driven (-0.40)
#      → Higher mileage tends to reduce resale value.
#      * year ↔ km_driven (-0.46)
#      → Newer bikes generally have lower kilometers driven.
# 3. Moderate Positive Correlation
#      * selling_price ↔ year (0.39)
#      → Newer bikes usually sell for higher prices.
# 4. Perfect Negative Correlation (Artificial)
#      * seller_type_Dealer ↔ seller_type_Individual (-1.0)
#      → This is due to one-hot encoding of a binary column (they’re exact opposites).
#
# **Most meaningful insights:**
#      * Bike age (year) and usage (km_driven) are the strongest predictors of resale value.
#      * Ex-showroom price is almost directly proportional to resale value.

# %% [markdown]
# 10. Summarize your findings in a brief report:
#
#      ● What are the most important factors affecting a bike's selling price?
#
#      ● Mention any data cleaning or feature engineering you performed.
#
# -   **Key Factors Affecting Selling Price**
#      1. Ex-showroom Price (Strongest Factor)
#         * Correlation of 0.92 with selling price.
#         * Higher original showroom prices strongly predict higher resale value.
#      2. Year of Manufacture (Bike Age)
#         * Moderate positive correlation (0.39) with selling price.
#         * Newer bikes tend to sell for more.
#      3. Kilometers Driven (Usage)
#         * Negative correlation (-0.40) with selling price.
#         * More kilometers reduce resale value, as expected.
#      4. Seller Type
#         * Individuals sell bikes at higher average prices compared to dealers.
#         * However, this factor has weaker correlation compared to bike age, mileage, and showroom price.
#
#      **Data Cleaning & Feature Engineering Performed**
#      1. Missing Values
#         * Found 435 missing values in ex_showroom_price.
#         * Suggested imputation by using the median value per model-year group.
#      2. Outlier Treatment
#         * Used IQR method on km_driven to remove unrealistic outliers (e.g., 880,000 km).
#         * Reduced max mileage to 86,000 km, making the dataset more realistic.
#      3. Categorical Encoding
#         * Converted seller_type into numeric format using one-hot encoding.
#         * Columns seller_type_Dealer and seller_type_Individual created.
#      4. Exploratory Visualizations
#         * Histogram showed most bikes are sold in the ₹20k–₹100k range.
#         * Scatter plot confirmed newer bikes sell for higher prices.
#         * Heatmap highlighted ex_showroom_price, year, and km_driven as the main predictors.
#
#      **Conclusion:**
#
#      The most important factors influencing resale price are:
#        * Ex-showroom price,
#        * Year of manufacture, and
#        * Kilometers driven.
